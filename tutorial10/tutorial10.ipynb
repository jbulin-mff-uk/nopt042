# %% [markdown]
# # NOPT042 Constraint programming: Tutorial 10 - Modeling with sets

# %%
# %load_ext ipicat
# Out:
# Picat version 3.2#8

# %% [markdown]
# ## Modelling with sets
# \begin{itemize}
#     \item A subset $X\subseteq\{1,\dots,n\}$:
#     \code{\\var set of 1..n: x;
#     \\array[1..n] of var bool: ch;
#     \\constraint link\_set\_to\_booleans(x,ch); \\\% i in x <-> ch[i]
#     }
#
#     \item fixed cardinality subset:
#     \code{\\var set of 1..n: x; constraint card(x) = k;
#     \\array[1..k] of var 1..n: x;
#     \\constraint all\_different(x);
#     }
#     \item bounded cardinality subset:
#     \code{\\var set of 1..n: x; card(x)>=l; card(x) <= u;
#     \\array[1..u] of var 0..n: x;
#     \\constraint alldifferent\_except\_0(x);
#     }
#
#
# \item Many global constraints have variants for sets, e.g.:
# \code{\\all\_different(array [\$X] of var set of int: S);
# \\all\_disjoint(array [\$X] of var set of int: S);
# }
# \end{itemize}
# \end{frame}

# %% [markdown]
# ## Example: Ramsay's partition
#
# Partition the integers 1 to $n$ into three parts, such that for no part are there three different numbers with two adding to the third. For which $n$ is it possible?

# %% [markdown]
# ## Example: Finite projective plane

# %% [markdown]
# # Homework: golfer TODO
#
# The [Social Golfer Problem](https://en.wikipedia.org/wiki/Social_golfer_problem), see also problem description on [CSPLib](https://www.csplib.org/Problems/prob010/).
#
# Running
#
# ```
# picat golfer.pi
# ```
# TODO how long is the schedule or just output the schedule
#
# should return the optimal value of `??` and some representation of the route of each vehicle.
